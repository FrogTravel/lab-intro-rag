# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="color: #FF6347;">Self-Guided Lab: Retrieval-Augmented Generation (RAGs)</h1>
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExZ3FsdzRveTBrenMxM3VnbDMwaTJxN2NnZm50aGFibXk1NzNnY2Q0MCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/LR5ZBwZHv02lmpVoEU/giphy.gif" alt="NLP Gif" style="width: 300px; height: 150px; object-fit: cover; object-position: center;">
# </div>

# %% [markdown]
# <h1 style="color: #FF6347;">Data Storage & Retrieval</h1>

# %% [markdown]
# <h2 style="color: #FF8C00;">PyPDFLoader</h2>
#
# `PyPDFLoader` is a lightweight Python library designed to streamline the process of loading and parsing PDF documents for text processing tasks. It is particularly useful in Retrieval-Augmented Generation workflows where text extraction from PDFs is required.
#
# - **What Does PyPDFLoader Do?**
#   - Extracts text from PDF files, retaining formatting and layout.
#   - Simplifies the preprocessing of document-based datasets.
#   - Supports efficient and scalable loading of large PDF collections.
#
# - **Key Features:**
#   - Compatible with popular NLP libraries and frameworks.
#   - Handles multi-page PDFs and embedded images (e.g., OCR-compatible setups).
#   - Provides flexible configurations for structured text extraction.
#
# - **Use Cases:**
#   - Preparing PDF documents for retrieval-based systems in RAGs.
#   - Automating the text extraction pipeline for document analysis.
#   - Creating datasets from academic papers, technical manuals, and reports.

# %%
# %pip install langchain langchain_community pypdf
# %pip install termcolor langchain_openai langchain-huggingface sentence-transformers chromadb langchain_chroma tiktoken openai python-dotenv
# Out:
# Requirement already satisfied: langchain in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (1.2.14)
# Requirement already satisfied: langchain_community in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: pypdf in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (6.9.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain) (1.2.25)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain) (1.1.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.25)
# Requirement already satisfied: packaging>=23.2.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.12)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (4.13.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain_community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain_community) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain_community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain_community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain_community) (2.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (1.1.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: termcolor in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (3.3.0)
# Requirement already satisfied: langchain_openai in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (1.1.12)
# Requirement already satisfied: langchain-huggingface in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (1.2.1)
# Requirement already satisfied: sentence-transformers in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (5.3.0)
# Requirement already satisfied: chromadb in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (1.5.5)
# Requirement already satisfied: langchain_chroma in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: tiktoken in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (0.12.0)
# Requirement already satisfied: openai in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (2.30.0)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.21 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain_openai) (1.2.25)
# Requirement already satisfied: regex>=2022.1.18 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from tiktoken) (2026.2.19)
# Requirement already satisfied: requests>=2.26.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_openai) (0.7.25)
# Requirement already satisfied: packaging>=23.2.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_openai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_openai) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_openai) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.21->langchain_openai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-huggingface) (1.9.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: filelock>=3.10.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.4.3)
# Requirement already satisfied: typer in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.24.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from sentence-transformers) (5.5.0)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from sentence-transformers) (2.4.1)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from sentence-transformers) (1.17.0)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: build>=1.0.3 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: pydantic-settings>=2.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (2.13.1)
# Requirement already satisfied: pybase64>=1.4.1 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.42.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (1.24.4)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: pypika>=0.48.9 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: pyproject_hooks in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.6.3)
# Requirement already satisfied: durationpy>=0.7 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.5)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.61b0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: setuptools<82 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (80.10.1)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: joblib>=1.3.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import CharacterTextSplitter, RecursiveCharacterTextSplitter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h3 style="color: #FF8C00;">Loading the Documents</h3>

# %%
# File path for the document

file_path = "ai-for-everyone.pdf"

# %% [markdown]
# <h3 style="color: #FF8C00;">Documents into pages</h3>
#
# The `PyPDFLoader` library allows efficient loading and splitting of PDF documents into smaller, manageable parts for NLP tasks.
#
# This functionality is particularly useful in workflows requiring granular text processing, such as Retrieval-Augmented Generation (RAG).

# %%
# Load and split the document
loader = PyPDFLoader(file_path)
pages = loader.load_and_split()
len(pages)
# Out:
# 297

# %% [markdown]
# <h3 style="color: #FF8C00;">Pages into Chunks</h3>
#
#
# ####  RecursiveCharacterTextSplitter in LangChain
#
# The `RecursiveCharacterTextSplitter` is the **recommended splitter** in LangChain when you want to break down long documents into smaller, semantically meaningful chunks — especially useful in **RAG pipelines**, where clean context chunks lead to better LLM responses.
#
# ####  Parameters
#
# | Parameter       | Description                                                                 |
# |-----------------|-----------------------------------------------------------------------------|
# | `chunk_size`    | The **maximum number of characters** allowed in a chunk (e.g., `1000`).     |
# | `chunk_overlap` | The number of **overlapping characters** between consecutive chunks (e.g., `200`). This helps preserve context continuity. |
#
# ####  How it works
# `RecursiveCharacterTextSplitter` attempts to split the text **intelligently**, trying the following separators in order:
# 1. Paragraphs (`"\n\n"`)
# 2. Lines (`"\n"`)
# 3. Sentences or words (`" "`)
# 4. Individual characters (as a last resort)
#
# This makes it ideal for handling **natural language documents**, such as PDFs, articles, or long reports, without breaking sentences or paragraphs in awkward ways.

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)
chunks = text_splitter.split_documents(pages)

len(chunks)
# Out:
# 1096

# %% [markdown]
# ####  Alternative: CharacterTextSplitter
#
# `CharacterTextSplitter` is a simpler splitter that breaks text into chunks based **purely on character count**, without trying to preserve any natural language structure.
#
# ##### Example:
# ```python
# from langchain.text_splitter import CharacterTextSplitter
#
# text_splitter = CharacterTextSplitter(
#     chunk_size=1000,
#     chunk_overlap=200
# )
# ````
#
# This method is faster and more predictable but may split text in the middle of a sentence or paragraph, which can hurt performance in downstream tasks like retrieval or QA.
#
# ---
#
# #### Comparison Table
#
# | Feature                        | RecursiveCharacterTextSplitter | CharacterTextSplitter     |
# | ------------------------------ | ------------------------------ | ------------------------- |
# | Structure-aware splitting      |  Yes                          |  No                      |
# | Preserves sentence/paragraphs  |  Yes                          |  No                      |
# | Risk of splitting mid-sentence |  Minimal                     |  High                   |
# | Ideal for RAG/document QA      |  Highly recommended           |  Only if structured text |
# | Performance speed              |  Slightly slower             |  Faster                  |
#
# ---
#
# #### Recommendation
#
# Use `RecursiveCharacterTextSplitter` for most real-world document processing tasks, especially when building RAG pipelines or working with structured natural language content like PDFs or articles.

# %% [markdown]
# ## Best Practices for Choosing Chunk Size in RAG
#
# ### Best Practices for Chunk Size in RAG
#
# | Factor                      | Recommendation                                                                                                                                                                                          |
# | ---------------------------| ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **LLM context limit**       | Choose a chunk size that lets you retrieve multiple chunks **without exceeding the model’s token limit**. For example, GPT-4o supports 128k tokens, but with GPT-3.5 (16k) or GPT-4 (32k), keep it modest. |
# | **Chunk size (in characters)** | Typically: **500–1,000 characters** per chunk → ~75–200 tokens. This fits well for retrieval + prompt without context overflow.                                                                           |
# | **Chunk size (in tokens)**  | If using token-based splitter (e.g. `TokenTextSplitter`): aim for **100–300 tokens** per chunk.                                                                                                            |
# | **Chunk overlap**           | Use **overlap of 10–30%** (e.g., 100–300 characters or ~50 tokens) to preserve context across chunk boundaries and avoid cutting off important ideas mid-sentence.                                        |
# | **Document structure**      | Use **`RecursiveCharacterTextSplitter`** to preserve semantic boundaries (paragraphs, sentences) instead of arbitrary cuts.                                                                                |
# | **Task type**               | For **question answering**, smaller chunks (~500–800 chars) reduce noise.<br>For **summarization**, slightly larger chunks (~1000–1500) are OK.                                                          |
# | **Embedding model**         | Some models (e.g., `text-embedding-3-large`) can handle long input. But still, smaller chunks give **finer-grained retrieval**, which improves relevance.                                                  |
# | **Query type**              | If users ask **very specific questions**, small focused chunks are better. For broader queries, bigger chunks might help.                                                                                  |
#
#
# ### Rule of Thumb
#
# | Use Case                 | Chunk Size      | Overlap |
# | ------------------------| --------------- | ------- |
# | Factual Q&A              | 500–800 chars   | 100–200 |
# | Summarization            | 1000–1500 chars | 200–300 |
# | Technical documents      | 400–700 chars   | 100–200 |
# | Long reports/books       | 800–1200 chars  | 200–300 |
# | Small LLMs (≤16k tokens) | ≤800 chars      | 100–200 |
#
#
# ### Avoid
#
# - Chunks >2000 characters: risks context overflow.
# - No overlap: may lose key information between chunks.

# %% [markdown]
# <h2 style="color: #FF8C00;">Embeddings</h2>
#
# Embeddings transform text into dense vector representations, capturing semantic meaning and contextual relationships. They are essential for efficient document retrieval and similarity analysis.
#
# - **What are OpenAI Embeddings?**
#   - Pre-trained embeddings like `text-embedding-3-large` generate high-quality vector representations for text.
#   - Encapsulate semantic relationships in the text, enabling robust NLP applications.
#
# - **Key Features of `text-embedding-3-large`:**
#   - Large-scale embedding model optimized for accuracy and versatility.
#   - Handles diverse NLP tasks, including retrieval, classification, and clustering.
#   - Ideal for applications with high-performance requirements.
#
# - **Benefits:**
#   - Reduces the need for extensive custom training.
#   - Provides state-of-the-art performance in retrieval-augmented systems.
#   - Compatible with RAGs to create powerful context-aware models.

# %%
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("OPENAI_API_KEY")
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %% [markdown]
# <h2 style="color: #FF8C00;">ChromaDB</h2>
#
# ChromaDB is a versatile vector database designed for efficiently storing and retrieving embeddings. It integrates seamlessly with embedding models to enable high-performance similarity search and context-based retrieval.
#
# ### Workflow Overview:
# - **Step 1:** Generate embeddings using a pre-trained model (e.g., OpenAI's `text-embedding-3-large`).
# - **Step 2:** Store the embeddings in ChromaDB for efficient retrieval and similarity calculations.
# - **Step 3:** Use the stored embeddings to perform searches, matching, or context-based retrieval.
#
# ### Key Features of ChromaDB:
# - **Scalability:** Handles large-scale datasets with optimized indexing and search capabilities.
# - **Speed:** Provides fast and accurate retrieval of embeddings for real-time applications.
# - **Integration:** Supports integration with popular frameworks and libraries for embedding generation.

# %%
from langchain_community.vectorstores import Chroma

# %%
db = Chroma.from_documents(chunks, embeddings, persist_directory="./chroma_db_LAB_1")
print("ChromaDB created with document embeddings.")
# Out:
# ChromaDB created with document embeddings.

# %% [markdown]
# <h1 style="color: #FF6347;">Retrieving Documents</h1>

# %% [markdown]
# ### Exercice1: Write a user question that someone might ask about your book’s topic or content.

# %%
user_question = "What is the environmental impact of AI?" # User question
retrieved_docs = db.similarity_search(user_question, k=10) # k is the number of documents to retrieve

# %%
# Display top results
for i, doc in enumerate(retrieved_docs[:3]): # Display top 3 results
    print(f"Document {i+1}:\n{doc.page_content[36:1000]}") # Display content
# Out:
# Document 1:
# ochai Benkler explained, the digital giant
# has ‘the technical, the contractual, technical and organizational means to pro-
# mote the projects that suit its goals’ (ibid. 2019). Hence, ‘Industry has mobilized
# to shape the science, morality and laws of Artificial Intelligence’ (ibid. 2019).
# Moreover, this portrayal of AI as the magic, divine hand that will rescue
# society also obfuscates the materiality of the infrastructures that are central to
# the environmental question that has been so consistently and artfully ignored
# (Brevini 2020). AI relies on technology, machines and infrastructures that
# deplete scarce resources in their production, consumption and disposal, thus
# increasing amounts of energy in their use, and exacerbating problems of waste
# and pollution. AI generates an array of environmental problems, most nota -
# bly energy consumption and emissions, material toxicity and electronic waste
# Document 2:
# ncreased 300,000 times from 2012 and 2018, with no end in
# sight (Amodei and Hernandez 2018).
# Such computation is energy intensive. Cloud platforms thus rely on access
# to energy infrastructures. According to Pearce (2018), the largest data cen -
# tres consume as much power as a city of a million people, and in total, data
# centres consume ‘more than 2 percent of the world’s electricity and emit roughly
# as much CO₂ as the airline industry’ . Google, Microsoft and Baidu derive 15%,
# 31% and 67% of their energy, respectively, from coal (Cook 2017, 8). Efforts to
# ‘green’ the cloud by increasing renewable energy sources are ongoing, but many
# such campaigns consist of offsetting or buying carbon credits and do not actu-
# ally mean that clouds are contributing less to CO₂ production.
# Distribution
# Machine learning requires sources of data, such as social media platforms. Nei-
# ther can it function without storage for data, the substantial work which goes
# Document 3:
#  data and computational power are made available, then the
# hardware cost of AI research and development will continue to rise. If the
# reconfiguration of AI is to occur in a local context, and if it wishes to remain on
# functional par with capitalist AI, it will have to devote considerable resources
# to the requisite hardware and figure out how to make their operation more
# ecologically feasible.
# But perhaps seizing data centres is not necessary for the reconfiguration of
# AI. Some commentators hope to shift the computational load from the central-
# ised cloud onto individual devices in a technique called decentralised or edge
# computing. While increasing amounts of edge computing seem likely as com-
# ponents continue to decrease in size, data centres will always offer more space
# and thus more total computing power. The expert consensus seems to be that
# with existing technology it is ‘not possible to move Cloud-levels of compute

# %% [markdown]
# <h2 style="color: #FF8C00;">Preparing Content for GenAI</h2>

# %%
def _get_document_prompt(docs):
    prompt = "\n"
    for doc in docs:
        prompt += "\nContent:\n"
        prompt += doc.page_content + "\n\n"
    return prompt

# %%
# Generate a formatted context from the retrieved documents
formatted_context = _get_document_prompt(retrieved_docs)
print("Context formatted for GPT model.")
# Out:
# Context formatted for GPT model.

# %% [markdown]
# <h2 style="color: #FF8C00;">ChatBot Architecture</h2>

# %% [markdown]
# ### Exercice2: Write a prompt that is relevant and tailored to the content and style of your book.

# %%
prompt = f"""
Answer the question based on the following context:\n{formatted_context}\n\nQuestion: {user_question}
"""

# %%
import openai

# %% [markdown]
# ### Exercice3: Tune parameters like temperature, and penalties to control how creative, focused, or varied the model's responses are.

# %%
# Set up GPT client and parameters
client = openai.OpenAI()
model_params = {
    'model': 'gpt-4o',
    'temperature': 0.7,  # Increase creativity
    'max_tokens': 1024,  # Allow for longer responses
    'top_p': 0.8,        # Use nucleus sampling
    'frequency_penalty': 0.5,  # Reduce repetition
    'presence_penalty': 0.5    # Encourage new topics
}

# %% [markdown]
# <h1 style="color: #FF6347;">Response</h1>

# %%
messages = [{'role': 'user', 'content': prompt}]
completion = client.chat.completions.create(messages=messages, **model_params, timeout=120)

# %%
answer = completion.choices[0].message.content
print(answer)
# Out:
# The environmental impact of AI is significant and multifaceted. AI technologies, particularly those involving machine learning and deep learning, require substantial computational power, which in turn demands large amounts of energy. This energy consumption contributes to carbon emissions, similar to those produced by the airline industry. Data centers, essential for cloud computing and AI operations, consume more than 2% of the world's electricity.
#
# Additionally, the production, consumption, and disposal of technology used for AI lead to the depletion of scarce resources and exacerbate problems related to waste and pollution. The infrastructure supporting AI generates various environmental issues such as material toxicity and electronic waste.
#
# Efforts are being made to reduce these impacts by increasing the use of renewable energy sources; however, many initiatives involve offsetting or buying carbon credits rather than reducing actual CO₂ production. Moreover, while there is interest in decentralizing computation through edge computing to reduce reliance on centralized data centers, these centers still provide more space and total computing power.
#
# Overall, despite some "greening" efforts in data centers, it remains uncertain whether these can keep pace with the growing computational demands driven by advances in machine learning.

# %% [markdown]
# <img src="https://miro.medium.com/v2/resize:fit:824/1*GK56xmDIWtNQAD_jnBIt2g.png" alt="NLP Gif" style="width: 500px">

# %% [markdown]
# <h2 style="color: #FF6347;">Cosine Similarity</h2>
#
# **Cosine similarity** is a metric used to measure the alignment or similarity between two vectors, calculated as the cosine of the angle between them. It is the **most common metric used in RAG pipelines** for vector retrieval.. It provides a scale from -1 to 1:
#
# - **-1**: Vectors are completely opposite.
# - **0**: Vectors are orthogonal (uncorrelated or unrelated).
# - **1**: Vectors are identical.

# %% [markdown]
# <img src="https://storage.googleapis.com/lds-media/images/cosine-similarity-vectors.original.jpg" alt="NLP Gif" style="width: 700px">

# %% [markdown]
# <h2 style="color: #FF6347;">Keyword Highlighting</h2>
#
# Highlighting important keywords helps users quickly understand the relevance of the retrieved text to their query.

# %%
from termcolor import colored

# %% [markdown]
# The `highlight_keywords` function is designed to highlight specific keywords within a given text. It replaces each keyword in the text with a highlighted version using the `colored` function from the `termcolor` library.

# %%
def highlight_keywords(text, keywords):
    for keyword in keywords:
        text = text.replace(keyword, colored(keyword, 'green', attrs=['bold']))
    return text

# %% [markdown]
# ### Exercice4: add your keywords

# %%
query_keywords = ["Amazon"] # add your keywords
for i, doc in enumerate(retrieved_docs[:1]):
    snippet = doc.page_content[:200]
    highlighted = highlight_keywords(snippet, query_keywords)
    print(f"Snippet {i+1}:\n{highlighted}\n{'-'*80}")
# Out:
# Snippet 1:
# Amazon (Benkler 2019). As scholar Y ochai Benkler explained, the digital giant
# has ‘the technical, the contractual, technical and organizational means to pro-
# mote the projects that suit its goals’ (
# --------------------------------------------------------------------------------

# %% [markdown]
# 1. `query_keywords` is a list of keywords to be highlighted.
# 2. The loop iterates over the first document in retrieved_docs.
# 3. For each document, a snippet of the first 200 characters is extracted.
# 4. The highlight_keywords function is called to highlight the keywords in the snippet.
# 5. The highlighted snippet is printed along with a separator line.

# %% [markdown]
# <h1 style="color: #FF6347;">Bonus</h1>

# %% [markdown]
# **Try loading one of your own PDF books and go through the steps again to explore how the pipeline works with your content**:
